# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import requests as req
import json
from datetime import datetime, timedelta

pd.options.display.max_rows = 400

# %% [markdown]
# # Retrieve RW Metadata

# %%
# Base URL for getting dataset metadata from RW API
# Metadata = Data that describes Data 
url = "https://api.resourcewatch.org/v1/dataset?sort=slug,-provider,userId&status=saved&includes=metadata,vocabulary,widget,layer"

# page[size] tells the API the maximum number of results to send back
# There are currently between 200 and 300 datasets on the RW API
payload = { "application":"rw", "page[size]": 1000}

# Request all datasets, and extract the data from the response
res = req.get(url, params=payload)
data = res.json()["data"]

#############################################################

### Convert the json object returned by the API into a pandas DataFrame
# Another option: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.json.json_normalize.html
datasets_on_api = {}
for ix, dset in enumerate(data):
    atts = dset["attributes"]
    metadata = atts["metadata"]
    layers = atts["layer"]
    widgets = atts["widget"]
    tags = atts["vocabulary"]
    datasets_on_api[atts["name"]] = {
        "rw_id":dset["id"],
        "table_name":atts["tableName"],
        "provider":atts["provider"],
        "date_updated":atts["updatedAt"],
        "num_metadata":len(metadata),
        "metadata": metadata,
        "num_layers":len(layers),
        "layers": layers,
        "num_widgets":len(widgets),
        "widgets": widgets,
        "num_tags":len(tags),
        "tags":tags
    }

# Create the DataFrame, name the index, and sort by date_updated
# More recently updated datasets at the top
current_datasets_on_api = pd.DataFrame.from_dict(datasets_on_api, orient='index')
current_datasets_on_api.index.rename("Dataset", inplace=True)
current_datasets_on_api.sort_values(by=["date_updated"], inplace=True, ascending = False)

# %% [markdown]
# # Import, Format, Export data

# %% [markdown]
# ## Connecting refugee data with wri_bounds

# %%
refugees = pd.read_excel('Refugee_CSV.xlsx').set_index('Country')
bounds = req.get('https://raw.githubusercontent.com/wri/wri-bounds/master/dist/all_primary_countries.geojson').json()

# %%
refugees
# Out:
#                                            Refugees
# Country
# Afghanistan                                 13969.0
# Albania                                     41333.0
# Algeria                                      2509.0
# Andorra                                        38.0
# Angola                                       1663.0
# Antigua and Barbuda                            19.0
# Argentina                                    1082.0
# Armenia                                     43432.0
# Australia                                       9.0
# Austria                                        37.0
# Azerbaijan                                   7463.0
# Bahamas                                      1300.0
# Bahrain                                       333.0
# Bangladesh                                  12841.0
# Barbados                                       13.0
# Belarus                                     17797.0
# Belgium                                       337.0
# Belize                                        277.0
# Benin                                         713.0
# Bhutan                                        708.0
# Bolivia                                      1106.0
# Bosnia and Herzegovina                       2044.0
# Botswana                                       37.0
# Brazil                                       6231.0
# Brunei                                          0.0
# Bulgaria                                     7442.0
# Burkina Faso                                 6359.0
# Burundi                                      5526.0
# Ivory Coast                                 14127.0
# Cape Verde                                      0.0
# Cambodia                                     3489.0
# Cameroon                                    59294.0
# Canada                                        459.0
# Cayman Islands                                 33.0
# Central African Republic                     2156.0
# Chad                                         3864.0
# Chile                                         573.0
# China                                      630855.0
# Colombia                                   161402.0
# Comoros                                        57.0
# Congo                                       17259.0
# Costa Rica                                    959.0
# Côte d'Ivoire                                1389.0
# Croatia                                       719.0
# Cuba                                         7336.0
# Cyprus                                         17.0
# Czech Republic                                296.0
# Slovenia                                       81.0
# Somalia                                     38689.0
# South Africa                                  839.0
# South Sudan                                    27.0
# Spain                                         109.0
# Sri Lanka                                   13715.0
# Stateless                                    9633.0
# Sudan                                       18701.0
# Suriname                                      140.0
# Swaziland                                      25.0
# Sweden                                         86.0
# Switzerland                                    18.0
# Syrian Arab Rep.                            30700.0
# Tajikistan                                   1852.0
# Thailand                                      235.0
# The former Yugoslav Republic of Macedonia    1896.0
# Togo                                        16589.0
# Tonga                                           7.0
# Trinidad and Tobago                           569.0
# Tunisia                                       421.0
# Turkey                                       4898.0
# Turkmenistan                                 2534.0
# Turks and Caicos Islands                      103.0
# Uganda                                      13006.0
# Ukraine                                     15322.0
# United Arab Emirates                          313.0
# United Kingdom                                580.0
# United Rep. of Tanzania                      1549.0
# Uruguay                                       116.0
# Uzbekistan                                  15434.0
# Various/Unknown                             24147.0
# Venezuela (Bolivarian Republic of)          59963.0
# Viet Nam                                     2599.0
# Yemen                                        3979.0
# Zambia                                        806.0
# Zimbabwe                                    15360.0

# %%
for ix, cntry in enumerate(bounds['features']):
    name = cntry['properties']['name']
    if name not in refugees.index:
        print(name)
        new_name = input('What should new name be?')
        if new_name: 
            bounds['features'][ix]['properties']['name'] = new_name
            bounds['features'][ix]['properties']['refugee_count'] = refugees.loc[new_name, 'Refugees']
        else:
            print('no data')
            bounds['features'][ix]['properties']['refugee_count'] = None
    else:
        bounds['features'][ix]['properties']['refugee_count'] = refugees.loc[name, 'Refugees']
# Out:
# Kiribati
# What should new name be?
# no data
# South Korea
# What should new name be?Rep. of Korea
# Laos
# What should new name be?Lao People's Dem. Rep.
# Liechtenstein
# What should new name be?
# no data
# Luxembourg
# What should new name be?
# no data
# Moldova
# What should new name be?Rep. of Moldova
# Macedonia
# What should new name be?The former Yugoslav Republic of Macedonia
# North Korea
# What should new name be?Dem. People's Rep. of Korea
# Russia
# What should new name be?Russian Federation
# Solomon Islands
# What should new name be?
# no data
# Republic of Serbia
# What should new name be?Serbia and Kosovo (S/RES/1244 (1999))
# Sao Tome and Principe
# What should new name be?
# no data
# Syria
# What should new name be?Syrian Arab Rep.
# Timor-Leste
# What should new name be?
# no data
# Tuvalu
# What should new name be?
# no data
# United Republic of Tanzania
# What should new name be?United Rep. of Tanzania
# United States of America
# What should new name be?
# no data
# Venezuela
# What should new name be?Venezuela (Bolivarian Republic of)
# Vietnam
# What should new name be?Viet Nam
# Vanuatu
# What should new name be?
# no data
# Samoa
# What should new name be?
# no data

# %%
json.dump(bounds, open('bounds_with_refugee_counts.geojson','w'))

# %% [markdown]
# ## Creating data frame for scatter plots

# %%
refugees = refugees.reset_index()
refugees
# Out:
#                                        Country  Refugees
# 0                                  Afghanistan   13969.0
# 1                                      Albania   41333.0
# 2                                      Algeria    2509.0
# 3                                      Andorra      38.0
# 4                                       Angola    1663.0
# 5                          Antigua and Barbuda      19.0
# 6                                    Argentina    1082.0
# 7                                      Armenia   43432.0
# 8                                    Australia       9.0
# 191                                      Yemen    3979.0
# 192                                     Zambia     806.0
# 193                                   Zimbabwe   15360.0

# %% [markdown]
# ### Water Stress

# %%
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

sql = "SELECT * FROM {}"
DT_FORMAT = '%Y-%m-%dT%H:%M:%SZ'

today = datetime.today()
five_years_ago = today - timedelta(days=360*5)
cutoff = datetime.strftime(five_years_ago, DT_FORMAT)

#[ds for ds in current_datasets_on_api.index if 'stress' in ds.lower()]

ds = [ds for ds in current_datasets_on_api.index if 'stress' in ds.lower()][0]
ds_id = current_datasets_on_api.loc[ds, 'rw_id']
table_name = current_datasets_on_api.loc[ds, 'table_name']

#query_sql = sql.format(table_name, cutoff)
query_sql = sql.format(table_name)
query = query_base.format(ds_id, query_sql) 
res = req.get(query).json()
water_stress = pd.DataFrame(res['data'])

# %%
water_stress = water_stress[['all_sectors', 'name']]

# %% [markdown]
# ### GDP

# %%
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

sql = "SELECT * FROM {} WHERE year = 2015"
DT_FORMAT = '%Y-%m-%dT%H:%M:%SZ'

#[ds for ds in current_datasets_on_api.index if 'gross' in ds.lower()]

ds = [ds for ds in current_datasets_on_api.index if 'gross' in ds.lower()][0]
ds_id = current_datasets_on_api.loc[ds, 'rw_id']
table_name = current_datasets_on_api.loc[ds, 'table_name']

query_sql = sql.format(table_name)
query = query_base.format(ds_id, query_sql) 
res = req.get(query).json()

gdp = pd.DataFrame(res['data'])

# %%
gdp = gdp[['rw_country_code', 'rw_country_name', 'yr_data']]

# %% [markdown]
# ### Political Freedoms Index

# %%
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

sql = "SELECT * FROM {} "
DT_FORMAT = '%Y-%m-%dT%H:%M:%SZ'

#[ds for ds in current_datasets_on_api.index if 'political' in ds.lower()]

ds = [ds for ds in current_datasets_on_api.index if 'political' in ds.lower()][1]
ds_id = current_datasets_on_api.loc[ds, 'rw_id']
table_name = current_datasets_on_api.loc[ds, 'table_name']

query_sql = sql.format(table_name)
query = query_base.format(ds_id, query_sql) 
res = req.get(query).json()

political_freedoms = pd.DataFrame(res['data'])

# %%
political_freedoms = political_freedoms[['rw_country_code', 'rw_country_name', 'total_aggr']]

# %% [markdown]
# ## Joined

# %%
tmp = political_freedoms.merge(gdp, left_on='rw_country_code', right_on='rw_country_code')

# %%
aliases = tmp[['rw_country_code', 'rw_country_name_x']]
aliases.columns = ['code', 'name']

# %%
water_stress
# Out:
#      all_sectors                              name
# 0       5.000000               Antigua and Barbuda
# 1       5.000000                           Bahrain
# 2       5.000000                          Barbados
# 3       5.000000                           Comoros
# 4       5.000000                            Cyprus
# 5       5.000000                          Dominica
# 6       5.000000                           Jamaica
# 7       5.000000                             Malta
# 8       5.000000                             Qatar
# 9       5.000000                       Saint Lucia
# 10      5.000000  Saint Vincent and the Grenadines
# 11      5.000000                        San Marino
# 12      5.000000                         Singapore
# 13      5.000000               Trinidad and Tobago
# 112     1.010346                         Guatemala
# 113     1.010016                         Nicaragua
# 114     1.008669                           Vietnam
# 115     0.982449                           Finland
# 116     0.952931                           Denmark
# 117     0.914442                            Brazil
# 118     0.912859                             Sudan
# 119     0.863199                           Uruguay
# 120     0.835612                           Romania
# 121     0.824087                        Mozambique
# 122     0.682812                             Kenya
# 123     0.677155                           Bolivia
# 124     0.647534                        Bangladesh
# 125     0.640418                          Zimbabwe
# 126     0.611777                          Ethiopia
# 127     0.604109                        Mauritania
# 128     0.596268                  Papua New Guinea
# 129     0.591421                           Belarus
# 130     0.583519                Republic of Serbia
# 131     0.536396                 Equatorial Guinea
# 132     0.522389                              Chad
# 133     0.508071                      Sierra Leone
# 134     0.494865                           Hungary
# 135     0.462063                     Liechtenstein
# 136     0.455283                           Somalia
# 137     0.450202                            Bhutan
# 138     0.442281                          Cambodia
# 139     0.427577             Republic of the Congo
# 140     0.422003                            Panama
# 141     0.416834                            Gambia
# 142     0.400525                            Norway
# 143     0.351614                            Latvia
# 144     0.327354                          Colombia
# 145     0.322036                           Austria
# 146     0.308811                        Montenegro
# 147     0.303092                           Myanmar
# 148     0.293372                           Nigeria
# 149     0.273278                           Liberia
# 150     0.253345                          Suriname
# 151     0.214814                           Senegal
# 152     0.204415                              Mali
# 153     0.197466                          Slovakia
# 154     0.166058                     Guinea Bissau
# 155     0.136670                           Iceland
# 156     0.120468                              Togo
# 157     0.112431                             Niger
# 158     0.108840                             Ghana
# 159     0.107044                          Cameroon
# 160     0.105264                            Malawi
# 161     0.102101                            Taiwan
# 162     0.077685                            Zambia
# 163     0.068148                          Honduras
# 164     0.058242                            Guinea
# 165     0.044008                       Ivory Coast
# 166     0.027711                          Slovenia
# 167     0.019933            Bosnia and Herzegovina
# 168     0.017394                           Croatia
# 169     0.014155                              Laos
# 170     0.011150                          Paraguay
# 171     0.008372                            Brunei
# 172     0.006046  Democratic Republic of the Congo
# 173     0.000343                            Uganda
# 174     0.000004                      Burkina Faso
# 175     0.000000                             Benin
# 176     0.000000                           Burundi
# 177     0.000000          Central African Republic
# 178     0.000000                            Rwanda
# 179     0.000000                       South Sudan
# 180     0.000000                        Cape Verde
# 181     0.000000                           Curacao
# 182     0.000000    Federated States of Micronesia
# 183     0.000000                              Fiji
# 184     0.000000                           Grenada
# 185     0.000000                          Kiribati
# 186     0.000000                          Maldives
# 187     0.000000                  Marshall Islands
# 188     0.000000                         Mauritius
# 189     0.000000                             Nauru
# 190     0.000000                             Palau
# 191     0.000000             Saint Kitts and Nevis
# 192     0.000000                             Samoa
# 193     0.000000             Sao Tome and Principe
# 194     0.000000                        Seychelles
# 195     0.000000                   Solomon Islands
# 196     0.000000                       The Bahamas
# 197     0.000000                             Tonga
# 198     0.000000                            Tuvalu
# 199     0.000000                           Vanuatu

# %%
def find_rw_country_code(name, aliases):
    if name in aliases['name'].values:
        code = aliases.loc[aliases['name'].isin([name]), 'code'].values[0]
        return code
    else:
        print(name)
        code = input("Country Code?")
        if code:
            return code
        else:
            return None
    
water_stress['rw_country_code'] = water_stress.apply(lambda row: find_rw_country_code(row['name'], aliases), axis = 1)
water_stress
# Out:
# Western Sahara
# Country Code?ESH
# East Timor
# Country Code?TLS
# Palestine
# Country Code?PSE
# Somaliland
# Country Code?
# Vatican
# Country Code?VAT
# Kosovo
# Country Code?
# Romania
# Country Code?ROU
# Republic of the Congo
# Country Code?COG
# Taiwan
# Country Code?TWN
# Curacao
# Country Code?
# /Users/nathansuberi/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#      all_sectors                              name rw_country_code
# 0       5.000000               Antigua and Barbuda             ATG
# 1       5.000000                           Bahrain             BHR
# 2       5.000000                          Barbados             BRB
# 3       5.000000                           Comoros             COM
# 4       5.000000                            Cyprus             CYP
# 5       5.000000                          Dominica             DMA
# 6       5.000000                           Jamaica             JAM
# 7       5.000000                             Malta             MLT
# 8       5.000000                             Qatar             QAT
# 9       5.000000                       Saint Lucia             LCA
# 10      5.000000  Saint Vincent and the Grenadines             VCT
# 11      5.000000                        San Marino             SMR
# 12      5.000000                         Singapore             SGP
# 13      5.000000               Trinidad and Tobago             TTO
# 14      5.000000              United Arab Emirates             ARE
# 15      5.000000                    Western Sahara             ESH
# 16      4.992351                      Saudi Arabia             SAU
# 17      4.964874                            Kuwait             KWT
# 18      4.913786                              Oman             OMN
# 19      4.840212                             Libya             LBY
# 20      4.825386                            Israel             ISR
# 21      4.821998                        Kyrgyzstan             KGZ
# 22      4.806092                        East Timor             TLS
# 23      4.781554                              Iran             IRN
# 24      4.674046                             Yemen             YEM
# 25      4.633905                         Palestine             PSE
# 26      4.594450                            Jordan             JOR
# 27      4.540997                           Lebanon             LBN
# 28      4.379483                        Somaliland            None
# 29      4.316672                        Uzbekistan             UZB
# 30      4.310025                          Pakistan             PAK
# 31      4.299610                      Turkmenistan             TKM
# 32      4.236047                           Morocco             MAR
# 33      4.046934                          Mongolia             MNG
# 34      4.018548                        Kazakhstan             KAZ
# 35      4.009098                       Afghanistan             AFG
# 36      3.972669                           Lesotho             LSO
# 37      3.851933                             Syria             SYR
# 38      3.725614                             Spain             ESP
# 39      3.584887                             India             IND
# 40      3.543805                       South Korea             KOR
# 41      3.528026                        Tajikistan             TJK
# 42      3.516054                            Mexico             MEX
# 43      3.511488                         Australia             AUS
# 44      3.487299                Dominican Republic             DOM
# 45      3.483185                              Iraq             IRQ
# 46      3.444267                           Algeria             DZA
# 47      3.441953                           Tunisia             TUN
# 48      3.399435                           Vatican             VAT
# 49      3.391520                        Azerbaijan             AZE
# 50      3.390809                          Djibouti             DJI
# 51      3.350268                             Italy             ITA
# 52      3.338300                          Portugal             PRT
# 53      3.333262                       Philippines             PHL
# 54      3.326591                           Andorra             AND
# 55      3.272571                            Greece             GRC
# 56      3.264861                         Indonesia             IDN
# 57      3.205366                             Chile             CHL
# 58      3.201609                              Peru             PER
# 59      3.192193                              Cuba             CUB
# 60      3.164518                           Belgium             BEL
# 61      3.105144                         Swaziland             SWZ
# 62      3.067363                           Armenia             ARM
# 63      3.054322                             Japan             JPN
# 64      3.040457                      South Africa             ZAF
# 65      3.020970                            Turkey             TUR
# 66      3.018732                           Eritrea             ERI
# 67      3.007875                         Sri Lanka             LKA
# 68      2.944769                             China             CHN
# 69      2.917040                           Ireland             IRL
# 70      2.888310          United States of America             USA
# 71      2.750275                           Estonia             EST
# 72      2.664468                            Monaco             MCO
# 73      2.645752                         Macedonia             MKD
# 74      2.628115                    United Kingdom             GBR
# 75      2.513095                         Argentina             ARG
# 76      2.508314                        Luxembourg             LUX
# 77      2.402084                             Nepal             NPL
# 78      2.375955                             Haiti             HTI
# 79      2.299918                         Venezuela             VEN
# 80      2.095905                           Ukraine             UKR
# 81      2.087356                          Malaysia             MYS
# 82      2.059945                       North Korea             PRK
# 83      1.941372                        Costa Rica             CRI
# 84      1.895269                           Germany             DEU
# 85      1.895066                           Albania             ALB
# 86      1.882401                           Namibia             NAM
# 87      1.860604                           Ecuador             ECU
# 88      1.779325                            Guyana             GUY
# 89      1.750634                            France             FRA
# 90      1.728848                       Netherlands             NLD
# 91      1.698024                          Thailand             THA
# 92      1.559075                             Gabon             GAB
# 93      1.539987                            Angola             AGO
# 94      1.511845                           Georgia             GEO
# 95      1.498342       United Republic of Tanzania             TZA
# 96      1.494649                       El Salvador             SLV
# 97      1.462672                           Moldova             MDA
# 98      1.362974                          Botswana             BWA
# 99      1.351786                       New Zealand             NZL
# 100     1.347722                            Belize             BLZ
# 101     1.327988                             Egypt             EGY
# 102     1.307267                            Poland             POL
# 103     1.304243                            Sweden             SWE
# 104     1.288331                            Kosovo            None
# 105     1.265798                          Bulgaria             BGR
# 106     1.247566                        Madagascar             MDG
# 107     1.234853                            Russia             RUS
# 108     1.205767                            Canada             CAN
# 109     1.193841                         Lithuania             LTU
# 110     1.134583                    Czech Republic             CZE
# 111     1.064087                       Switzerland             CHE
# 112     1.010346                         Guatemala             GTM
# 113     1.010016                         Nicaragua             NIC
# 114     1.008669                           Vietnam             VNM
# 115     0.982449                           Finland             FIN
# 116     0.952931                           Denmark             DNK
# 117     0.914442                            Brazil             BRA
# 118     0.912859                             Sudan             SDN
# 119     0.863199                           Uruguay             URY
# 120     0.835612                           Romania             ROU
# 121     0.824087                        Mozambique             MOZ
# 122     0.682812                             Kenya             KEN
# 123     0.677155                           Bolivia             BOL
# 124     0.647534                        Bangladesh             BGD
# 125     0.640418                          Zimbabwe             ZWE
# 126     0.611777                          Ethiopia             ETH
# 127     0.604109                        Mauritania             MRT
# 128     0.596268                  Papua New Guinea             PNG
# 129     0.591421                           Belarus             BLR
# 130     0.583519                Republic of Serbia             SRB
# 131     0.536396                 Equatorial Guinea             GNQ
# 132     0.522389                              Chad             TCD
# 133     0.508071                      Sierra Leone             SLE
# 134     0.494865                           Hungary             HUN
# 135     0.462063                     Liechtenstein             LIE
# 136     0.455283                           Somalia             SOM
# 137     0.450202                            Bhutan             BTN
# 138     0.442281                          Cambodia             KHM
# 139     0.427577             Republic of the Congo             COG
# 140     0.422003                            Panama             PAN
# 141     0.416834                            Gambia             GMB
# 142     0.400525                            Norway             NOR
# 143     0.351614                            Latvia             LVA
# 144     0.327354                          Colombia             COL
# 145     0.322036                           Austria             AUT
# 146     0.308811                        Montenegro             MNE
# 147     0.303092                           Myanmar             MMR
# 148     0.293372                           Nigeria             NGA
# 149     0.273278                           Liberia             LBR
# 150     0.253345                          Suriname             SUR
# 151     0.214814                           Senegal             SEN
# 152     0.204415                              Mali             MLI
# 153     0.197466                          Slovakia             SVK
# 154     0.166058                     Guinea Bissau             GNB
# 155     0.136670                           Iceland             ISL
# 156     0.120468                              Togo             TGO
# 157     0.112431                             Niger             NER
# 158     0.108840                             Ghana             GHA
# 159     0.107044                          Cameroon             CMR
# 160     0.105264                            Malawi             MWI
# 161     0.102101                            Taiwan             TWN
# 162     0.077685                            Zambia             ZMB
# 163     0.068148                          Honduras             HND
# 164     0.058242                            Guinea             GIN
# 165     0.044008                       Ivory Coast             CIV
# 166     0.027711                          Slovenia             SVN
# 167     0.019933            Bosnia and Herzegovina             BIH
# 168     0.017394                           Croatia             HRV
# 169     0.014155                              Laos             LAO
# 170     0.011150                          Paraguay             PRY
# 171     0.008372                            Brunei             BRN
# 172     0.006046  Democratic Republic of the Congo             COD
# 173     0.000343                            Uganda             UGA
# 174     0.000004                      Burkina Faso             BFA
# 175     0.000000                             Benin             BEN
# 176     0.000000                           Burundi             BDI
# 177     0.000000          Central African Republic             CAF
# 178     0.000000                            Rwanda             RWA
# 179     0.000000                       South Sudan             SSD
# 180     0.000000                        Cape Verde             CPV
# 181     0.000000                           Curacao            None
# 182     0.000000    Federated States of Micronesia             FSM
# 183     0.000000                              Fiji             FJI
# 184     0.000000                           Grenada             GRD
# 185     0.000000                          Kiribati             KIR
# 186     0.000000                          Maldives             MDV
# 187     0.000000                  Marshall Islands             MHL
# 188     0.000000                         Mauritius             MUS
# 189     0.000000                             Nauru             NRU
# 190     0.000000                             Palau             PLW
# 191     0.000000             Saint Kitts and Nevis             KNA
# 192     0.000000                             Samoa             WSM
# 193     0.000000             Sao Tome and Principe             STP
# 194     0.000000                        Seychelles             SYC
# 195     0.000000                   Solomon Islands             SLB
# 196     0.000000                       The Bahamas             BHS
# 197     0.000000                             Tonga             TON
# 198     0.000000                            Tuvalu             TUV
# 199     0.000000                           Vanuatu             VUT

# %%
tmp = tmp.merge(water_stress, left_on='rw_country_code', right_on='rw_country_code')
tmp
# Out:
#     rw_country_code                 rw_country_name_x  total_aggr  \
# 0               THA                          Thailand          32
# 1               TJK                        Tajikistan          11
# 2               ARG                         Argentina          82
# 3               MRT                        Mauritania          30
# 4               MCO                            Monaco          84
# 5               ZWE                          Zimbabwe          32
# 6               YEM                             Yemen          14
# 7               BHR                           Bahrain          12
# 8               VNM                           Vietnam          20
# 9               VEN                         Venezuela          30
# 10              CRI                        Costa Rica          91
# 11              COD  Democratic Republic of the Congo          19
# 12              COG                 Republic of Congo          27
# 13              CZE                    Czech Republic          94
# 14              CIV                       Ivory Coast          52
# 15              BRB                          Barbados          97
# 16              STP             Sao Tome and Principe          81
# 17              SWE                            Sweden         100
# 18              MUS                         Mauritius          89
# 19              TUV                            Tuvalu          94
# 20              UGA                            Uganda          35
# 21              VUT                           Vanuatu          80
# 22              UKR                           Ukraine          61
# 23              TKM                      Turkmenistan           4
# 24              UZB                        Uzbekistan           3
# 25              PAK                          Pakistan          43
# 26              SRB                Republic of Serbia          76
# 27              SLB                   Solomon Islands          71
# 28              ESP                             Spain          94
# 29              SUR                          Suriname          77
# 30              KOR                       South Korea          82
# 31              IRN                              Iran          17
# 32              AUT                           Austria          95
# 33              LIE                     Liechtenstein          91
# 34              LAO                              Laos          12
# 35              LBR                           Liberia          62
# 36              KGZ                        Kyrgyzstan          37
# 37              MWI                            Malawi          63
# 38              SWZ                         Swaziland          18
# 39              SWZ                         Swaziland          18
# 40              PAN                            Panama          83
# 41              PRY                          Paraguay          64
# 42              PHL                       Philippines          63
# 43              RUS                            Russia          20
# 44              SAU                      Saudi Arabia          10
# 45              PRT                          Portugal          97
# 46              PER                              Peru          72
# 47              SSD                       South Sudan           4
# 48              CHE                       Switzerland          96
# 49              SMR                        San Marino          97
# 50              GAB                             Gabon          32
# 51              DEU                           Germany          95
# 52              GRC                            Greece          84
# 53              NOR                            Norway         100
# 54              NER                             Niger          49
# 55              SEN                           Senegal          78
# 56              ALB                           Albania          68
# 57              DZA                           Algeria          35
# 58              MLT                             Malta          96
# 59              MLI                              Mali          45
# 60              MDG                        Madagascar          56
# 61              MYS                          Malaysia          44
# 62              MDV                          Maldives          40
# 63              MAR                           Morocco          41
# 64              MEX                            Mexico          65
# 65              NAM                           Namibia          77
# 66              MNG                          Mongolia          85
# 67              MMR                           Myanmar          32
# 68              PRK                       North Korea           3
# 69              NPL                             Nepal          52
# 70              OMN                              Oman          25
# 71              NRU                             Nauru          81
# 72              NLD                       Netherlands          99
# 73              NGA                           Nigeria          50
# 74              NZL                       New Zealand          98
# 75              NIC                         Nicaragua          47
# 76              POL                            Poland          89
# 77              PNG                  Papua New Guinea          64
# 78              SYR                             Syria          -1
# 79              SDN                             Sudan           6
# 80              LKA                         Sri Lanka          56
# 81              TZA       United Republic of Tanzania          58
# 82              BLZ                            Belize          87
# 83              BGD                        Bangladesh          47
# 84              BEL                           Belgium          95
# 85              BHS                       The Bahamas          91
# 86              DOM                Dominican Republic          68
# 87              MHL                  Marshall Islands          92
# 88              VCT  Saint Vincent and the Grenadines          91
# 89              SVN                          Slovenia          92
# 90              MOZ                        Mozambique          53
# 91              SVK                          Slovakia          89
# 92              SOM                           Somalia           5
# 93              AUS                         Australia          98
# 94              AGO                            Angola          24
# 95              BOL                           Bolivia          68
# 96              BWA                          Botswana          72
# 97              BGR                          Bulgaria          80
# 98              BRA                            Brazil          79
# 99              BFA                      Burkina Faso          63
# 100             CMR                          Cameroon          24
# 101             SGP                         Singapore          51
# 102             SLE                      Sierra Leone          66
# 103             ZAF                      South Africa          78
# 104             TUR                            Turkey          38
# 105             TUN                           Tunisia          78
# 106             GBR                    United Kingdom          95
# 107             ARE              United Arab Emirates          20
# 108             URY                           Uruguay          98
# 109             USA          United States of America          89
# 110             ZMB                            Zambia          56
# 111             DMA                          Dominica          95
# 112             LCA                       Saint Lucia          92
# 113             GEO                           Georgia          64
# 114             GIN                            Guinea          41
# 115             GHA                             Ghana          83
# 116             IRQ                              Iraq          27
# 117             IRL                           Ireland          96
# 118             HND                          Honduras          46
# 119             IND                             India          77
# 120             KNA             Saint Kitts and Nevis          89
# 121             KIR                          Kiribati          92
# 122             LVA                            Latvia          87
# 123             HRV                           Croatia          87
# 124             ATG               Antigua and Barbuda          83
# 125             AND                           Andorra          95
# 126             AFG                       Afghanistan          24
# 127             AZE                        Azerbaijan          14
# 128             BLR                           Belarus          20
# 129             BEN                             Benin          82
# 130             KHM                          Cambodia          31
# 131             BIH            Bosnia and Herzegovina          55
# 132             CHN                             China          15
# 133             CAN                            Canada          99
# 134             CAF          Central African Republic          10
# 135             CHL                             Chile          94
# 136             COL                          Colombia          64
# 137             TCD                              Chad          18
# 138             CUB                              Cuba          15
# 139             DNK                           Denmark          97
# 140             FIN                           Finland         100
# 141             ETH                          Ethiopia          12
# 142             FJI                              Fiji          59
# 143             ECU                           Ecuador          57
# 144             ERI                           Eritrea           3
# 145             EGY                             Egypt          26
# 146             FRA                            France          90
# 147             EST                           Estonia          94
# 148             GNB                     Guinea Bissau          40
# 149             IDN                         Indonesia          65
# 150             GUY                            Guyana          74
# 151             HUN                           Hungary          76
# 152             ISL                           Iceland          97
# 153             KEN                             Kenya          51
# 154             ITA                             Italy          89
# 155             KAZ                        Kazakhstan          22
# 156             JPN                             Japan          96
# 157             LTU                         Lithuania          91
# 158             LBY                             Libya          13
# 159             MDA                           Moldova          62
# 160             COM                           Comoros          55
# 161             GRD                           Grenada          89
# 162             BRN                            Brunei          29
# 163             BDI                           Burundi          19
# 164             BTN                            Bhutan          55
# 165             ARM                           Armenia          45
# 166             DJI                          Djibouti          26
# 167             GNQ                 Equatorial Guinea           8
# 168             CPV                        Cape Verde          90
# 169             CYP                            Cyprus          94
# 170             PLW                             Palau          92
# 171             SLV                       El Salvador          70
# 172             GMB                            Gambia          20
# 173             GTM                         Guatemala          54
# 174             HTI                             Haiti          39
# 175             JOR                            Jordan          37
# 176             ISR                            Israel          80
# 177             KWT                            Kuwait          36
# 178             FSM    Federated States of Micronesia          93
# 179             JAM                           Jamaica          75
# 180             LUX                        Luxembourg          98
# 181             TTO               Trinidad and Tobago          81
# 182             TLS                       Timor-Leste          65
# 183             LBN                           Lebanon          44
# 184             QAT                             Qatar          26
# 185             LSO                           Lesotho          64
# 186             WSM                             Samoa          80
# 187             MKD                         Macedonia          57
# 188             MNE                        Montenegro          69
# 189             RWA                            Rwanda          24
# 190             TON                             Tonga          74
# 191             SYC                        Seychelles          71
# 192             TGO                              Togo          48
#
# 191                        Seychelles  1.375604e+09     0.000000
# 192                              Togo  4.087775e+09     0.120468
#
#                                  name
# 0                            Thailand
# 1                          Tajikistan
# 2                           Argentina
# 3                          Mauritania
# 4                              Monaco
# 5                            Zimbabwe
# 6                               Yemen
# 7                             Bahrain
# 8                             Vietnam
# 9                           Venezuela
# 10                         Costa Rica
# 11   Democratic Republic of the Congo
# 12              Republic of the Congo
# 13                     Czech Republic
# 14                        Ivory Coast
# 15                           Barbados
# 16              Sao Tome and Principe
# 17                             Sweden
# 18                          Mauritius
# 19                             Tuvalu
# 20                             Uganda
# 21                            Vanuatu
# 22                            Ukraine
# 23                       Turkmenistan
# 24                         Uzbekistan
# 25                           Pakistan
# 26                 Republic of Serbia
# 27                    Solomon Islands
# 28                              Spain
# 29                           Suriname
# 30                        South Korea
# 31                               Iran
# 32                            Austria
# 33                      Liechtenstein
# 34                               Laos
# 35                            Liberia
# 36                         Kyrgyzstan
# 37                             Malawi
# 38                          Swaziland
# 39                          Swaziland
# 40                             Panama
# 41                           Paraguay
# 42                        Philippines
# 43                             Russia
# 44                       Saudi Arabia
# 45                           Portugal
# 46                               Peru
# 47                        South Sudan
# 48                        Switzerland
# 49                         San Marino
# 50                              Gabon
# 51                            Germany
# 52                             Greece
# 53                             Norway
# 54                              Niger
# 55                            Senegal
# 56                            Albania
# 57                            Algeria
# 58                              Malta
# 59                               Mali
# 60                         Madagascar
# 61                           Malaysia
# 62                           Maldives
# 63                            Morocco
# 64                             Mexico
# 65                            Namibia
# 66                           Mongolia
# 67                            Myanmar
# 68                        North Korea
# 69                              Nepal
# 70                               Oman
# 71                              Nauru
# 72                        Netherlands
# 73                            Nigeria
# 74                        New Zealand
# 75                          Nicaragua
# 76                             Poland
# 77                   Papua New Guinea
# 78                              Syria
# 79                              Sudan
# 80                          Sri Lanka
# 81        United Republic of Tanzania
# 82                             Belize
# 83                         Bangladesh
# 84                            Belgium
# 85                        The Bahamas
# 86                 Dominican Republic
# 87                   Marshall Islands
# 88   Saint Vincent and the Grenadines
# 89                           Slovenia
# 90                         Mozambique
# 91                           Slovakia
# 92                            Somalia
# 93                          Australia
# 94                             Angola
# 95                            Bolivia
# 96                           Botswana
# 97                           Bulgaria
# 98                             Brazil
# 99                       Burkina Faso
# 100                          Cameroon
# 101                         Singapore
# 102                      Sierra Leone
# 103                      South Africa
# 104                            Turkey
# 105                           Tunisia
# 106                    United Kingdom
# 107              United Arab Emirates
# 108                           Uruguay
# 109          United States of America
# 110                            Zambia
# 111                          Dominica
# 112                       Saint Lucia
# 113                           Georgia
# 114                            Guinea
# 115                             Ghana
# 116                              Iraq
# 117                           Ireland
# 118                          Honduras
# 119                             India
# 120             Saint Kitts and Nevis
# 121                          Kiribati
# 122                            Latvia
# 123                           Croatia
# 124               Antigua and Barbuda
# 125                           Andorra
# 126                       Afghanistan
# 127                        Azerbaijan
# 128                           Belarus
# 129                             Benin
# 130                          Cambodia
# 131            Bosnia and Herzegovina
# 132                             China
# 133                            Canada
# 134          Central African Republic
# 135                             Chile
# 136                          Colombia
# 137                              Chad
# 138                              Cuba
# 139                           Denmark
# 140                           Finland
# 141                          Ethiopia
# 142                              Fiji
# 143                           Ecuador
# 144                           Eritrea
# 145                             Egypt
# 146                            France
# 147                           Estonia
# 148                     Guinea Bissau
# 149                         Indonesia
# 150                            Guyana
# 151                           Hungary
# 152                           Iceland
# 153                             Kenya
# 154                             Italy
# 155                        Kazakhstan
# 156                             Japan
# 157                         Lithuania
# 158                             Libya
# 159                           Moldova
# 160                           Comoros
# 161                           Grenada
# 162                            Brunei
# 163                           Burundi
# 164                            Bhutan
# 165                           Armenia
# 166                          Djibouti
# 167                 Equatorial Guinea
# 168                        Cape Verde
# 169                            Cyprus
# 170                             Palau
# 171                       El Salvador
# 172                            Gambia
# 173                         Guatemala
# 174                             Haiti
# 175                            Jordan
# 176                            Israel
# 177                            Kuwait
# 178    Federated States of Micronesia
# 179                           Jamaica
# 180                        Luxembourg
# 181               Trinidad and Tobago
# 182                        East Timor
# 183                           Lebanon
# 184                             Qatar
# 185                           Lesotho
# 186                             Samoa
# 187                         Macedonia
# 188                        Montenegro
# 189                            Rwanda
# 190                             Tonga
# 191                        Seychelles
# 192                              Togo

# %%
refugees['rw_country_code'] = refugees.apply(lambda row: find_rw_country_code(row['Country'], aliases), axis = 1)
# Out:
# Bahamas
# Country Code?BHS
# Cayman Islands
# Country Code?CYM
# Congo
# Country Code?COG
# Côte d'Ivoire
# Country Code?CIV
# Dem. People's Rep. of Korea
# Country Code?PRK
# Dem. Rep. of the Congo
# Country Code?COD
# Dominican Rep.
# Country Code?DOM
# French Guiana
# Country Code?GUF
# Gibraltar
# Country Code?GIB
# Guadeloupe
# Country Code?GLP
# Guinea-Bissau
# Country Code?GNB
# Iran (Islamic Rep. of)
# Country Code?IRN
# Lao People's Dem. Rep.
# Country Code?LAO
# Micronesia (Federated States of)
# Country Code?FSM
# New Caledonia
# Country Code?NCL
# Niue
# Country Code?NIU
# Palestinian
# Country Code?PSE
# Rep. of Korea
# Country Code?KOR
# Rep. of Moldova
# Country Code?MDA
# Romania
# Country Code?ROU
# Russian Federation
# Country Code?RUS
# Serbia and Kosovo (S/RES/1244 (1999))
# Country Code?SRB
# Stateless
# Country Code?
# Syrian Arab Rep.
# Country Code?SYR
# The former Yugoslav Republic of Macedonia
# Country Code?MKD
# Turks and Caicos Islands
# Country Code?TCA
# United Rep. of Tanzania
# Country Code?TZA
# Various/Unknown
# Country Code?
# Venezuela (Bolivarian Republic of)
# Country Code?VEN
# Viet Nam
# Country Code?VNM

# %%
tmp = tmp.merge(refugees, left_on='rw_country_code', right_on='rw_country_code')

# %%
tmp = tmp.drop(['rw_country_name_y', 'name', 'Country'], axis=1)

# %%
final_data = tmp
final_data.columns = ['Country Code', 'Country Name', 'Political Freedom Index', 'GDP', 'Water Stress, all Sectors', 'Refugees to US in Past 10 Years']
final_data.to_csv('scatterplotdata.csv')
